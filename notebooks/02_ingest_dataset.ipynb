# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fathomnet_voxel51.ingest_dataset import ingest

recreate = True
limit = 100
ingest(recreate=recreate, limit=limit)
# Out:
# Deleting existing dataset 'fathomnet-2025'...
# Creating dataset 'fathomnet-2025'...
# Loading /Users/mgustineli/github/fathomnet-voxel51/data/dataset_train.json...
#   Limiting to 100 samples
# Processing train: 100%|██████████| 100/100 [00:00<00:00, 2395.14it/s]
#   train: 100 samples
# Loading /Users/mgustineli/github/fathomnet-voxel51/data/dataset_test.json...
#   Limiting to 100 samples
# Processing test: 100%|██████████| 100/100 [00:00<00:00, 3013.39it/s]
#   test: 100 samples
# Adding 200 samples to dataset...
#  100% |█████████████████| 200/200 [4.8s elapsed, 0s remaining, 41.9 samples/s]
#
# Successfully created dataset 'fathomnet-2025'
# Total samples: 200
# Train samples: 100
# Test samples: 100
#
# Images remain in GCS. Filter by 'split' field or tags in the App.
